# %%
from pathlib import Path
import sys
import numpy as np

np_path = Path("/home/kobayashi/dataset/kitti/depth_anything3_150_730/2011_09_26_drive_0070_sync_02/0.npz")
data = np.load(np_path)

# %%
data["depth"].shape
# Out:
# (150, 224, 728)
